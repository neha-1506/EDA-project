# %% [markdown]
# #### EDA PROJECT

# %%
#Import Required Libraries
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#Loading the Dataset
ipl=pd.read_csv(r"C:\Users\lenovo\Downloads\matches.csv",header=0,index_col=0)
ipl
# Out:
#        season           city       date                        team1  \
# id
# 1        2017      Hyderabad   4/5/2017          Sunrisers Hyderabad
# 2        2017           Pune   4/6/2017               Mumbai Indians
# 3        2017         Rajkot   4/7/2017                Gujarat Lions
# 4        2017         Indore   4/8/2017       Rising Pune Supergiant
# 5        2017      Bangalore   4/8/2017  Royal Challengers Bangalore
# ...       ...            ...        ...                          ...
# 11347    2019         Mumbai   5/5/2019        Kolkata Knight Riders
# 11412    2019        Chennai   7/5/2019          Chennai Super Kings
# 11413    2019  Visakhapatnam   8/5/2019          Sunrisers Hyderabad
# 11414    2019  Visakhapatnam  10/5/2019               Delhi Capitals
# 11415    2019      Hyderabad  12/5/2019               Mumbai Indians
#
#                              team2                  toss_winner toss_decision  \
# id
# ...

# %%
#First Five Records of Dataset
ipl.head()
# Out:
#     season       city      date                        team1  \
# id
# 1     2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 2     2017       Pune  4/6/2017               Mumbai Indians
# 3     2017     Rajkot  4/7/2017                Gujarat Lions
# 4     2017     Indore  4/8/2017       Rising Pune Supergiant
# 5     2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision  \
# id
# 1   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 2        Rising Pune Supergiant       Rising Pune Supergiant         field
# 3         Kolkata Knight Riders        Kolkata Knight Riders         field
# 4               Kings XI Punjab              Kings XI Punjab         field
# 5              Delhi Daredevils  Royal Challengers Bangalore           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# id
# ...

# %%
#last Five Records of Dataset
ipl.tail()
# Out:
#        season           city       date                  team1  \
# id
# 11347    2019         Mumbai   5/5/2019  Kolkata Knight Riders
# 11412    2019        Chennai   7/5/2019    Chennai Super Kings
# 11413    2019  Visakhapatnam   8/5/2019    Sunrisers Hyderabad
# 11414    2019  Visakhapatnam  10/5/2019         Delhi Capitals
# 11415    2019      Hyderabad  12/5/2019         Mumbai Indians
#
#                      team2          toss_winner toss_decision  result  \
# id
# 11347       Mumbai Indians       Mumbai Indians         field  normal
# 11412       Mumbai Indians  Chennai Super Kings           bat  normal
# 11413       Delhi Capitals       Delhi Capitals         field  normal
# 11414  Chennai Super Kings  Chennai Super Kings         field  normal
# 11415  Chennai Super Kings       Mumbai Indians           bat  normal
#
#        dl_applied               winner  win_by_runs  win_by_wickets  \
# id
# 11347           0       Mumbai Indians            0               9
# ...

# %%
# shape returns the number of rows and columns of the dataframe
ipl.shape
# Out:
# (756, 17)

# %%
# the info method prints information  about dataframe.
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 756 entries, 1 to 11415
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           756 non-null    int64
#  1   city             749 non-null    object
#  2   date             756 non-null    object
#  3   team1            756 non-null    object
#  4   team2            756 non-null    object
#  5   toss_winner      756 non-null    object
#  6   toss_decision    756 non-null    object
#  7   result           756 non-null    object
#  8   dl_applied       756 non-null    int64
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
#  13  venue            756 non-null    object
#  14  umpire1          754 non-null    object
#  15  umpire2          754 non-null    object
#  16  umpire3          119 non-null    object
# ...

# %%
# dtype returns data type of each column in the dataframe
ipl.dtypes
# Out:
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
# description of all data in th e
